# %%
import os                               # Для работы с путями и директориями
import sys                              # Для работы с путями поиска модулей
import logging                          # Для логирования

from src.training.data_loader import LogDataLoader
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 5
#       2 import sys                              # Для работы с путями поиска модулей
#       3 import logging                          # Для логирования
# ----> 5 from src.training.data_loader import LogDataLoader
#
# ImportError: cannot import name 'LogDataLoader' from 'src.training.data_loader' (/home/user/log_loader/src/training/data_loader.py)

# %%
loader = LogDataLoader()
print(next(loader.get_data()))
# Out:
# Ошибка при соединении с БД: invalid integer value "5432               # Порт PostgreSQL" for connection option "port"
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 2
#       1 loader = LogDataLoader()
# ----> 2 print(next(loader.get_data()))
#
# File ~/log_loader/src/training/data_loader.py:45, in LogDataLoader.get_data(self, start_ts, end_ts)
#      41 DB_PARAMS = self.params.get_db_params()
#      43 try:
#      44     # Создаем соединение с БД
# ---> 45     with psycopg2.connect(**DB_PARAMS) as conn:
#      46         with conn.cursor(name='batched_cursor') as cursor:
#      47
#      48             # Запрос в БД
#      49             sql = """SELECT date_trunc('hour', timestamp) AS hour,
#      50                         COUNT(*) AS log_count
#      51                     FROM logs
#    (...)     54                     GROUP BY hour
#      55                     ORDER BY hour;"""
#
# File ~/log_loader/airflow_venv/lib/python3.12/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: invalid integer value "5432               # Порт PostgreSQL" for connection option "port"

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /home/user/project/airflow_venv/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from prophet) (1.3.0)
# Requirement already satisfied: numpy>=1.15.4 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from prophet) (3.10.3)
# Requirement already satisfied: pandas>=1.0.4 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from prophet) (2.3.0)
# Requirement already satisfied: holidays<1,>=0.25 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from prophet) (0.92)
# Requirement already satisfied: tqdm>=4.36.1 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in /home/user/project/airflow_venv/lib/python3.12/site-packages (from prophet) (6.4.0)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from python-dateutil<3,>=2.9.0.post0->holidays<1,>=0.25->prophet) (1.16.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (24.0)
# Requirement already satisfied: pillow>=8 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/user/project/airflow_venv/lib/python3.12/site-packages (from pandas>=1.0.4->prophet) (2024.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: /home/user/project/airflow_venv/bin/python3 -m pip install --upgrade pip
